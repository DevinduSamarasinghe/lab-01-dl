# %% [markdown]
# ## Lab 01 - Task 02
# #### Devindu Samarasinghe - IT21003332

# %% [markdown]
# #### Download the Au_nanoParticle_dataset.csv and load the data of the csv file as a dataframe in a new colab notebook. Do the below subtask with the dataset. Use any of the above libraries if needed.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

df = pd.read_csv('Au_nanoparticle_dataset.csv')
df.describe()
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %% [markdown]
# #### 1. Create a new dataframe by filtering all the columns [i.e., features] except N_total, N_bulk, N_surface and R_avg columns.

# %%
# Create a new dataframe with only the specified columns
feature_selected_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# Display the first few rows of the new dataframe
feature_selected_df.head()
# Out:
#    N_total  N_bulk  N_surface    R_avg
# 0     1599    1014        585  17.3706
# 1     1642    1034        608  17.6061
# 2     4637    3365       1272  25.3692
# 3     7189    5292       1897  29.7011
# 4    11004    8508       2496  34.2831

# %% [markdown]
# #### 2. Display the first 20 samples of this dataframe.

# %%
feature_selected_df.head(n=20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# #### 3. Calculate the mean, standard deviation and quartile values for each of the above 4 features.

# %%
describe = feature_selected_df.describe().T

#mean 
print(describe['mean'],"\n")


#std
print(describe['std'],"\n")

#quartiles 
print(describe.iloc[:,-4:])
# Out:
# N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# Name: mean, dtype: float64
#
# N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# Name: std, dtype: float64
#
#                    25%         50%          75%         max
# N_total    1061.000000  1867.00000  4503.000000  14277.0000
# N_bulk      618.750000  1199.00000  3183.000000  11580.0000
# N_surface   437.000000   666.00000  1301.750000   3190.0000
# R_avg        15.160725    18.62925    25.525125     39.2392

# %% [markdown]
# #### 4. Plot the histogram of each of these features in a 1x4 layout

# %%
fig, axes = plt.subplots(1,4, figsize=(20,5))  

for i, col in enumerate(feature_selected_df.columns):
    axes[i].hist(feature_selected_df[col], bins=20, color='red')
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
    
plt.show()

# %% [markdown]
# #### 5. Visualize the scatter plots and histograms of this dataframe using the pairplot functionality of seaborn library.

# %%
import seaborn as sns 
import pandas as pd 

sns.pairplot(feature_selected_df)

# %% [markdown]
# #### 6. Add the below code and change it such that,
#
# ##### a. plots on the diagonal contains the histogram of each feature along with the kernel density estimation plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming filtered_df is your dataframe containing the specified columns
g = sns.PairGrid(feature_selected_df)

g.map_upper(sns.histplot)
g.map_diag(sns.histplot, kde=True)
g.map_lower(sns.kdeplot)

plt.show()

# %% [markdown]
# #### b. Plots on the lower half [g.map_lower] contains the bivariate kernal density estimation plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.PairGrid(feature_selected_df)

g.map_upper(sns.histplot)
g.map_diag(sns.histplot, kde=True)
g.map_lower(sns.kdeplot)

plt.show()
